# %%
import pandas as pd

# Paths to your CSVs
csv1 = "combined-3-bose-maradji-emd.csv"
csv2 = "algorithm_results-subset5-marjushew-adwin.csv"

# Read
df1 = pd.read_csv(csv1)
df2 = pd.read_csv(csv2)

# Append rows, union columns; missing cells become NaN
combined = pd.concat([df1, df2], axis=0, ignore_index=True)

# (optional) save
combined.to_csv("combined-3-bose-maradji-emd-marjushev-adwin.csv", index=False)
